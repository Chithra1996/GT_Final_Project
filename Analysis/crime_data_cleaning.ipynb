# %%
import os
import pandas as pd
import datetime
import pymongo

# %%
# Create connection variable
conn = 'mongodb+srv://admin_user2021:<password>@cluster0.krwok.mongodb.net/test'

# Pass connection to the pymongo instance.
client = pymongo.MongoClient(conn)

# Connect to a database. Will create one if not already available.
db = client['pytodo']

# Create collection
db.forecast_value.drop()
db_c = db['forecast_value']

def csv_to_json(filename, header=None):
    data = pd.read_csv(filename, header=header)
    return data.to_dict('records')

db_c.insert_many(csv_to_json('predictions.csv', header = 0))

# %%
data20 = pd.read_csv("../raw_data/crime_data_2020.csv")
data20
# Out:
#        offense_id   rpt_date occur_date occur_time  poss_date poss_time  \
# 0       200021209   1/2/2020   1/2/2020      15:21   1/2/2020     15:35
# 1       200061707   1/6/2020   1/6/2020       0:00   1/6/2020     18:25
# 2       200100013  1/10/2020   1/9/2020      23:45  1/10/2020      0:00
# 3       200151818  1/16/2020  1/15/2020      17:15  1/15/2020     17:40
# 4       200180440  1/18/2020  1/18/2020       3:31  1/18/2020      3:31
# ...           ...        ...        ...        ...        ...       ...
# 14826   202670466  9/23/2020  9/22/2020      18:00  9/23/2020      9:00
# 14827   202670717  9/23/2020  9/22/2020      21:30  9/23/2020     10:00
# 14828   202680455  9/24/2020  9/23/2020      23:00  9/24/2020      7:00
# 14829   202731007  9/29/2020  9/26/2020      18:00  9/29/2020     14:30
# 14830   202731640  9/29/2020  9/29/2020      20:30  9/29/2020     21:00
#
#         beat apartment_office_prefix apartment_number                location  \
# 0      511.0                     NaN              NaN          12 BROAD ST SW
# 1      109.0                     NaN              NaN       785 PEYTON AVE NW
# 2      110.0                     NaN              NaN       1977 JONES AVE NW
# 3      401.0                     NaN              NaN  549 JOSEPH LOWERY BLVD
# 4      206.0                     NaN              NaN          28 IRBY AVE NW
# ...      ...                     ...              ...                     ...
# 14826  609.0                     NaN              NaN       1207 HARDEE ST NE
# 14827  609.0                     NaN              NaN      195 ARIZONA AVE NE
# 14828  609.0                     NaN              421    1661 LA FRANCE ST NE
# 14829  607.0                     NaN              NaN     694 SCHUYLER AVE SE
# 14830  504.0                     NaN              NaN      768 MARIETTA ST NW
#
#                watch  location_type UC2_Literal  UCR_Number  \
# 0      Evening Watch           21.0    HOMICIDE         110
# 1      Evening Watch            NaN    HOMICIDE         110
# 2      Morning Watch           20.0    HOMICIDE         110
# 3      Evening Watch           99.0    HOMICIDE         110
# 4      Morning Watch           13.0    HOMICIDE         110
# ...              ...            ...         ...         ...
# 14826  Morning Watch           20.0  AUTO THEFT         730
# 14827      Day Watch           18.0  AUTO THEFT         730
# 14828  Morning Watch           18.0  AUTO THEFT         730
# 14829  Evening Watch           20.0  AUTO THEFT         730
# 14830  Evening Watch           18.0  AUTO THEFT         730
#
#                  neighborhood npu       lat      long
# 0                    Downtown   M  33.75352 -84.39189
# 1                 Center Hill   J  33.77655 -84.46770
# 2              West Highlands   G  33.78738 -84.45208
# 3                    West End   T  33.74001 -84.41782
# 4           South Tuxedo Park   B  33.84102 -84.38018
# ...                       ...  ..       ...       ...
# 14826                Edgewood   O  33.75524 -84.34801
# 14827                Edgewood   O  33.75929 -84.33120
# 14828                Edgewood   O  33.76103 -84.33185
# 14829       Boulevard Heights   W  33.72520 -84.36533
# 14830  Marietta Street Artery   E  33.77331 -84.40403
#
# [14831 rows x 18 columns]

# %%
crime_2020 = data20.drop(columns=['apartment_office_prefix', 'apartment_number','location_type','npu','watch'])
crime_2020
# Out:
#        offense_id   rpt_date occur_date occur_time  poss_date poss_time  \
# 0       200021209   1/2/2020   1/2/2020      15:21   1/2/2020     15:35
# 1       200061707   1/6/2020   1/6/2020       0:00   1/6/2020     18:25
# 2       200100013  1/10/2020   1/9/2020      23:45  1/10/2020      0:00
# 3       200151818  1/16/2020  1/15/2020      17:15  1/15/2020     17:40
# 4       200180440  1/18/2020  1/18/2020       3:31  1/18/2020      3:31
# ...           ...        ...        ...        ...        ...       ...
# 14826   202670466  9/23/2020  9/22/2020      18:00  9/23/2020      9:00
# 14827   202670717  9/23/2020  9/22/2020      21:30  9/23/2020     10:00
# 14828   202680455  9/24/2020  9/23/2020      23:00  9/24/2020      7:00
# 14829   202731007  9/29/2020  9/26/2020      18:00  9/29/2020     14:30
# 14830   202731640  9/29/2020  9/29/2020      20:30  9/29/2020     21:00
#
#         beat                location UC2_Literal  UCR_Number  \
# 0      511.0          12 BROAD ST SW    HOMICIDE         110
# 1      109.0       785 PEYTON AVE NW    HOMICIDE         110
# 2      110.0       1977 JONES AVE NW    HOMICIDE         110
# 3      401.0  549 JOSEPH LOWERY BLVD    HOMICIDE         110
# 4      206.0          28 IRBY AVE NW    HOMICIDE         110
# ...      ...                     ...         ...         ...
# 14826  609.0       1207 HARDEE ST NE  AUTO THEFT         730
# 14827  609.0      195 ARIZONA AVE NE  AUTO THEFT         730
# 14828  609.0    1661 LA FRANCE ST NE  AUTO THEFT         730
# 14829  607.0     694 SCHUYLER AVE SE  AUTO THEFT         730
# 14830  504.0      768 MARIETTA ST NW  AUTO THEFT         730
#
#                  neighborhood       lat      long
# 0                    Downtown  33.75352 -84.39189
# 1                 Center Hill  33.77655 -84.46770
# 2              West Highlands  33.78738 -84.45208
# 3                    West End  33.74001 -84.41782
# 4           South Tuxedo Park  33.84102 -84.38018
# ...                       ...       ...       ...
# 14826                Edgewood  33.75524 -84.34801
# 14827                Edgewood  33.75929 -84.33120
# 14828                Edgewood  33.76103 -84.33185
# 14829       Boulevard Heights  33.72520 -84.36533
# 14830  Marietta Street Artery  33.77331 -84.40403
#
# [14831 rows x 13 columns]

# %%
data21 = pd.read_csv("../raw_data/crime_data_2021.csv")
#data21.head(2)

# %%
crime_2021 = data21.drop(columns=['occur_day','occur_day_num','zone','ibr_code','npu'])
crime_2021.dtypes
# Out:
# offense_id        int64
# rpt_date         object
# occur_date       object
# occur_time       object
# poss_date        object
# poss_time        object
# beat              int64
# location         object
# UC2_Literal      object
# neighborhood     object
# lat             float64
# long            float64
# dtype: object

# %%
frames = [crime_2021,crime_2021]

new_crime = pd.concat(frames)
new_crime
# Out:
#        offense_id   rpt_date occur_date occur_time  poss_date poss_time  beat  \
# 0        21140096  5/20/2021  5/19/2021      15:20  5/19/2021     15:25   103
# 1        21282015   8/6/2021   8/6/2021      22:23   8/6/2021     22:24   508
# 2        21320347   2/1/2021  1/31/2021      00:00   2/1/2021     06:53   509
# 3        21791668  6/28/2021  6/27/2021      21:17  6/28/2021     20:00   102
# 4        61583880  2/11/2021  2/11/2021      19:15  2/11/2021     20:29   401
# ...           ...        ...        ...        ...        ...       ...   ...
# 14080   212230459  8/11/2021  8/10/2021      19:30  8/11/2021     07:30   403
# 14081   212230498  8/11/2021   8/2/2021      14:30   8/2/2021     16:00   601
# 14082   212230549  8/11/2021  8/11/2021      09:21  8/11/2021     09:28   604
# 14083   212230568  8/11/2021  8/10/2021      21:40  8/11/2021     09:26   604
# 14084   212230651  8/11/2021  8/11/2021      09:00  8/11/2021     10:58   304
#
#                                                 location  \
# 0      1720 MARIETTA BLVD NW\r\nATLANTA, GA 30318\r\n...
# 1      300 PEACHTREE ST NE\r\nATLANTA, GA 30308\r\nUN...
# 2      229 COURTLAND ST NE\r\nATLANTA, GA 30303\r\nUN...
# 3      870 MAYSON TURNER RD NW\r\nATLANTA, GA 30314\r...
# 4      850 OAK ST SW\r\nATLANTA, GA 30310\r\nUNITED S...
# ...                                                  ...
# 14080  1099 SELWIN AVE SW\r\nATL, GA 30310\r\nUNITED ...
# 14081  1144 ROSEDALE DR NE\r\nATLANTA, GA 30306\r\nUN...
# 14082  141 HILLIARD ST SE\r\nATLANTA, GA 30312\r\nUNI...
# 14083  180 JACKSON ST NE\r\nATLANTA, GA 30312\r\nUNIT...
# 14084  1162 PRYOR ST SW\r\nATL, GA 30315\r\nUNITED ST...
#
#                 UC2_Literal       neighborhood        lat       long
# 0      LARCENY-FROM VEHICLE         Hills Park  33.801693 -84.436453
# 1      LARCENY-FROM VEHICLE           Downtown  33.762549 -84.387874
# 2      LARCENY-FROM VEHICLE           Downtown  33.760759 -84.383773
# 3       LARCENY-NON VEHICLE          Vine City  33.755768 -84.416631
# 4      LARCENY-FROM VEHICLE           West End  33.740594 -84.415800
# ...                     ...                ...        ...        ...
# 14080              BURGLARY       Oakland City  33.724966 -84.426435
# 14081   LARCENY-NON VEHICLE  Virginia Highland  33.779969 -84.349806
# 14082              BURGLARY       Sweet Auburn  33.750784 -84.376964
# 14083  LARCENY-FROM VEHICLE       Sweet Auburn  33.759313 -84.375614
# 14084   LARCENY-NON VEHICLE        Peoplestown  33.723348 -84.393203
#
# [28170 rows x 12 columns]

# %%
new_crime.dropna(how='any', inplace = True)
new_crime
# Out:
#        offense_id   rpt_date occur_date occur_time  poss_date poss_time  beat  \
# 0        21140096  5/20/2021  5/19/2021      15:20  5/19/2021     15:25   103
# 1        21282015   8/6/2021   8/6/2021      22:23   8/6/2021     22:24   508
# 2        21320347   2/1/2021  1/31/2021      00:00   2/1/2021     06:53   509
# 3        21791668  6/28/2021  6/27/2021      21:17  6/28/2021     20:00   102
# 4        61583880  2/11/2021  2/11/2021      19:15  2/11/2021     20:29   401
# ...           ...        ...        ...        ...        ...       ...   ...
# 14080   212230459  8/11/2021  8/10/2021      19:30  8/11/2021     07:30   403
# 14081   212230498  8/11/2021   8/2/2021      14:30   8/2/2021     16:00   601
# 14082   212230549  8/11/2021  8/11/2021      09:21  8/11/2021     09:28   604
# 14083   212230568  8/11/2021  8/10/2021      21:40  8/11/2021     09:26   604
# 14084   212230651  8/11/2021  8/11/2021      09:00  8/11/2021     10:58   304
#
#                                                 location  \
# 0      1720 MARIETTA BLVD NW\r\nATLANTA, GA 30318\r\n...
# 1      300 PEACHTREE ST NE\r\nATLANTA, GA 30308\r\nUN...
# 2      229 COURTLAND ST NE\r\nATLANTA, GA 30303\r\nUN...
# 3      870 MAYSON TURNER RD NW\r\nATLANTA, GA 30314\r...
# 4      850 OAK ST SW\r\nATLANTA, GA 30310\r\nUNITED S...
# ...                                                  ...
# 14080  1099 SELWIN AVE SW\r\nATL, GA 30310\r\nUNITED ...
# 14081  1144 ROSEDALE DR NE\r\nATLANTA, GA 30306\r\nUN...
# 14082  141 HILLIARD ST SE\r\nATLANTA, GA 30312\r\nUNI...
# 14083  180 JACKSON ST NE\r\nATLANTA, GA 30312\r\nUNIT...
# 14084  1162 PRYOR ST SW\r\nATL, GA 30315\r\nUNITED ST...
#
#                 UC2_Literal       neighborhood        lat       long
# 0      LARCENY-FROM VEHICLE         Hills Park  33.801693 -84.436453
# 1      LARCENY-FROM VEHICLE           Downtown  33.762549 -84.387874
# 2      LARCENY-FROM VEHICLE           Downtown  33.760759 -84.383773
# 3       LARCENY-NON VEHICLE          Vine City  33.755768 -84.416631
# 4      LARCENY-FROM VEHICLE           West End  33.740594 -84.415800
# ...                     ...                ...        ...        ...
# 14080              BURGLARY       Oakland City  33.724966 -84.426435
# 14081   LARCENY-NON VEHICLE  Virginia Highland  33.779969 -84.349806
# 14082              BURGLARY       Sweet Auburn  33.750784 -84.376964
# 14083  LARCENY-FROM VEHICLE       Sweet Auburn  33.759313 -84.375614
# 14084   LARCENY-NON VEHICLE        Peoplestown  33.723348 -84.393203
#
# [26292 rows x 12 columns]

# %%
new_crime[['Address', 'City', 'Country']] = new_crime['location'].str.split('\n', n=2, expand = True)
new_crime
new_crime[['city','state','zipcode']] = new_crime['City'].str.split(' ', n=2, expand = True)
new_crime.head(4)

new_crime.drop(columns=['location','City'], inplace = True)
new_crime
# Out:
#        offense_id   rpt_date occur_date occur_time  poss_date poss_time  beat  \
# 0        21140096  5/20/2021  5/19/2021      15:20  5/19/2021     15:25   103
# 1        21282015   8/6/2021   8/6/2021      22:23   8/6/2021     22:24   508
# 2        21320347   2/1/2021  1/31/2021      00:00   2/1/2021     06:53   509
# 3        21791668  6/28/2021  6/27/2021      21:17  6/28/2021     20:00   102
# 4        61583880  2/11/2021  2/11/2021      19:15  2/11/2021     20:29   401
# ...           ...        ...        ...        ...        ...       ...   ...
# 14080   212230459  8/11/2021  8/10/2021      19:30  8/11/2021     07:30   403
# 14081   212230498  8/11/2021   8/2/2021      14:30   8/2/2021     16:00   601
# 14082   212230549  8/11/2021  8/11/2021      09:21  8/11/2021     09:28   604
# 14083   212230568  8/11/2021  8/10/2021      21:40  8/11/2021     09:26   604
# 14084   212230651  8/11/2021  8/11/2021      09:00  8/11/2021     10:58   304
#
#                 UC2_Literal       neighborhood        lat       long  \
# 0      LARCENY-FROM VEHICLE         Hills Park  33.801693 -84.436453
# 1      LARCENY-FROM VEHICLE           Downtown  33.762549 -84.387874
# 2      LARCENY-FROM VEHICLE           Downtown  33.760759 -84.383773
# 3       LARCENY-NON VEHICLE          Vine City  33.755768 -84.416631
# 4      LARCENY-FROM VEHICLE           West End  33.740594 -84.415800
# ...                     ...                ...        ...        ...
# 14080              BURGLARY       Oakland City  33.724966 -84.426435
# 14081   LARCENY-NON VEHICLE  Virginia Highland  33.779969 -84.349806
# 14082              BURGLARY       Sweet Auburn  33.750784 -84.376964
# 14083  LARCENY-FROM VEHICLE       Sweet Auburn  33.759313 -84.375614
# 14084   LARCENY-NON VEHICLE        Peoplestown  33.723348 -84.393203
#
#                          Address        Country      city state  zipcode
# 0        1720 MARIETTA BLVD NW\r  UNITED STATES  ATLANTA,    GA  30318\r
# 1          300 PEACHTREE ST NE\r  UNITED STATES  ATLANTA,    GA  30308\r
# 2          229 COURTLAND ST NE\r  UNITED STATES  ATLANTA,    GA  30303\r
# 3      870 MAYSON TURNER RD NW\r  UNITED STATES  ATLANTA,    GA  30314\r
# 4                850 OAK ST SW\r  UNITED STATES  ATLANTA,    GA  30310\r
# ...                          ...            ...       ...   ...      ...
# 14080       1099 SELWIN AVE SW\r  UNITED STATES      ATL,    GA  30310\r
# 14081      1144 ROSEDALE DR NE\r  UNITED STATES  ATLANTA,    GA  30306\r
# 14082       141 HILLIARD ST SE\r  UNITED STATES  ATLANTA,    GA  30312\r
# 14083        180 JACKSON ST NE\r  UNITED STATES  ATLANTA,    GA  30312\r
# 14084         1162 PRYOR ST SW\r  UNITED STATES      ATL,    GA  30315\r
#
# [26292 rows x 16 columns]

# %%
city = new_crime[new_crime['city'].str.contains("at", case=False)]
city_list = city['city'].to_list()
new_crime["city"].replace(city_list,"Atlanta",inplace=True)
new_crime
# Out:
#        offense_id   rpt_date occur_date occur_time  poss_date poss_time  beat  \
# 0        21140096  5/20/2021  5/19/2021      15:20  5/19/2021     15:25   103
# 1        21282015   8/6/2021   8/6/2021      22:23   8/6/2021     22:24   508
# 2        21320347   2/1/2021  1/31/2021      00:00   2/1/2021     06:53   509
# 3        21791668  6/28/2021  6/27/2021      21:17  6/28/2021     20:00   102
# 4        61583880  2/11/2021  2/11/2021      19:15  2/11/2021     20:29   401
# ...           ...        ...        ...        ...        ...       ...   ...
# 14080   212230459  8/11/2021  8/10/2021      19:30  8/11/2021     07:30   403
# 14081   212230498  8/11/2021   8/2/2021      14:30   8/2/2021     16:00   601
# 14082   212230549  8/11/2021  8/11/2021      09:21  8/11/2021     09:28   604
# 14083   212230568  8/11/2021  8/10/2021      21:40  8/11/2021     09:26   604
# 14084   212230651  8/11/2021  8/11/2021      09:00  8/11/2021     10:58   304
#
#                 UC2_Literal       neighborhood        lat       long  \
# 0      LARCENY-FROM VEHICLE         Hills Park  33.801693 -84.436453
# 1      LARCENY-FROM VEHICLE           Downtown  33.762549 -84.387874
# 2      LARCENY-FROM VEHICLE           Downtown  33.760759 -84.383773
# 3       LARCENY-NON VEHICLE          Vine City  33.755768 -84.416631
# 4      LARCENY-FROM VEHICLE           West End  33.740594 -84.415800
# ...                     ...                ...        ...        ...
# 14080              BURGLARY       Oakland City  33.724966 -84.426435
# 14081   LARCENY-NON VEHICLE  Virginia Highland  33.779969 -84.349806
# 14082              BURGLARY       Sweet Auburn  33.750784 -84.376964
# 14083  LARCENY-FROM VEHICLE       Sweet Auburn  33.759313 -84.375614
# 14084   LARCENY-NON VEHICLE        Peoplestown  33.723348 -84.393203
#
#                          Address        Country     city state  zipcode
# 0        1720 MARIETTA BLVD NW\r  UNITED STATES  Atlanta    GA  30318\r
# 1          300 PEACHTREE ST NE\r  UNITED STATES  Atlanta    GA  30308\r
# 2          229 COURTLAND ST NE\r  UNITED STATES  Atlanta    GA  30303\r
# 3      870 MAYSON TURNER RD NW\r  UNITED STATES  Atlanta    GA  30314\r
# 4                850 OAK ST SW\r  UNITED STATES  Atlanta    GA  30310\r
# ...                          ...            ...      ...   ...      ...
# 14080       1099 SELWIN AVE SW\r  UNITED STATES  Atlanta    GA  30310\r
# 14081      1144 ROSEDALE DR NE\r  UNITED STATES  Atlanta    GA  30306\r
# 14082       141 HILLIARD ST SE\r  UNITED STATES  Atlanta    GA  30312\r
# 14083        180 JACKSON ST NE\r  UNITED STATES  Atlanta    GA  30312\r
# 14084         1162 PRYOR ST SW\r  UNITED STATES  Atlanta    GA  30315\r
#
# [26292 rows x 16 columns]

# %%
new_crime["city"].value_counts()
# Out:
# Atlanta       26076
# ADK,            210
# HAPEVILLE,        6
# Name: city, dtype: int64

# %%
new_crime["zipcode"].value_counts()
# Out:
# 30318\r         3418
# 30310\r         1958
# 30309\r         1910
# 30308\r         1792
# 30315\r         1784
# 30312\r         1662
# 30303\r         1600
# 30324\r         1536
# 30305\r         1344
# 30314\r         1228
# 30331\r         1186
# 30313\r         1098
# 30311\r         1020
# 30307\r          896
# 30316\r          804
# 30306\r          726
# 30326\r          672
# 30354\r          398
# 30317\r          388
# 30363\r          238
# 30327\r          206
# 30342\r          204
# 30319\r           72
# 30344\r           22
# 30336\r            8
# 30361\r            8
# 30328\r            6
# 30324-5018\r       6
# 30339\r            4
# 30380\r            2
# 30304\r            2
# 30375\r            2
# Name: zipcode, dtype: int64

# %%
new_crime = new_crime.loc[(new_crime['city'] == "Atlanta")]
new_crime
# Out:
#        offense_id   rpt_date occur_date occur_time  poss_date poss_time  beat  \
# 0        21140096  5/20/2021  5/19/2021      15:20  5/19/2021     15:25   103
# 1        21282015   8/6/2021   8/6/2021      22:23   8/6/2021     22:24   508
# 2        21320347   2/1/2021  1/31/2021      00:00   2/1/2021     06:53   509
# 3        21791668  6/28/2021  6/27/2021      21:17  6/28/2021     20:00   102
# 4        61583880  2/11/2021  2/11/2021      19:15  2/11/2021     20:29   401
# ...           ...        ...        ...        ...        ...       ...   ...
# 14080   212230459  8/11/2021  8/10/2021      19:30  8/11/2021     07:30   403
# 14081   212230498  8/11/2021   8/2/2021      14:30   8/2/2021     16:00   601
# 14082   212230549  8/11/2021  8/11/2021      09:21  8/11/2021     09:28   604
# 14083   212230568  8/11/2021  8/10/2021      21:40  8/11/2021     09:26   604
# 14084   212230651  8/11/2021  8/11/2021      09:00  8/11/2021     10:58   304
#
#                 UC2_Literal       neighborhood        lat       long  \
# 0      LARCENY-FROM VEHICLE         Hills Park  33.801693 -84.436453
# 1      LARCENY-FROM VEHICLE           Downtown  33.762549 -84.387874
# 2      LARCENY-FROM VEHICLE           Downtown  33.760759 -84.383773
# 3       LARCENY-NON VEHICLE          Vine City  33.755768 -84.416631
# 4      LARCENY-FROM VEHICLE           West End  33.740594 -84.415800
# ...                     ...                ...        ...        ...
# 14080              BURGLARY       Oakland City  33.724966 -84.426435
# 14081   LARCENY-NON VEHICLE  Virginia Highland  33.779969 -84.349806
# 14082              BURGLARY       Sweet Auburn  33.750784 -84.376964
# 14083  LARCENY-FROM VEHICLE       Sweet Auburn  33.759313 -84.375614
# 14084   LARCENY-NON VEHICLE        Peoplestown  33.723348 -84.393203
#
#                          Address        Country     city state  zipcode
# 0        1720 MARIETTA BLVD NW\r  UNITED STATES  Atlanta    GA  30318\r
# 1          300 PEACHTREE ST NE\r  UNITED STATES  Atlanta    GA  30308\r
# 2          229 COURTLAND ST NE\r  UNITED STATES  Atlanta    GA  30303\r
# 3      870 MAYSON TURNER RD NW\r  UNITED STATES  Atlanta    GA  30314\r
# 4                850 OAK ST SW\r  UNITED STATES  Atlanta    GA  30310\r
# ...                          ...            ...      ...   ...      ...
# 14080       1099 SELWIN AVE SW\r  UNITED STATES  Atlanta    GA  30310\r
# 14081      1144 ROSEDALE DR NE\r  UNITED STATES  Atlanta    GA  30306\r
# 14082       141 HILLIARD ST SE\r  UNITED STATES  Atlanta    GA  30312\r
# 14083        180 JACKSON ST NE\r  UNITED STATES  Atlanta    GA  30312\r
# 14084         1162 PRYOR ST SW\r  UNITED STATES  Atlanta    GA  30315\r
#
# [26076 rows x 16 columns]

# %%
new_crime["city"].value_counts()
# Out:
# Atlanta    26076
# Name: city, dtype: int64

# %%
new_crime['zipcode'] = new_crime['zipcode'].str.split("-").str[0]
new_crime
# Out:
# C:\Users\vinoy\anaconda3\envs\Pythondata\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        offense_id   rpt_date occur_date occur_time  poss_date poss_time  beat  \
# 0        21140096  5/20/2021  5/19/2021      15:20  5/19/2021     15:25   103
# 1        21282015   8/6/2021   8/6/2021      22:23   8/6/2021     22:24   508
# 2        21320347   2/1/2021  1/31/2021      00:00   2/1/2021     06:53   509
# 3        21791668  6/28/2021  6/27/2021      21:17  6/28/2021     20:00   102
# 4        61583880  2/11/2021  2/11/2021      19:15  2/11/2021     20:29   401
# ...           ...        ...        ...        ...        ...       ...   ...
# 14080   212230459  8/11/2021  8/10/2021      19:30  8/11/2021     07:30   403
# 14081   212230498  8/11/2021   8/2/2021      14:30   8/2/2021     16:00   601
# 14082   212230549  8/11/2021  8/11/2021      09:21  8/11/2021     09:28   604
# 14083   212230568  8/11/2021  8/10/2021      21:40  8/11/2021     09:26   604
# 14084   212230651  8/11/2021  8/11/2021      09:00  8/11/2021     10:58   304
#
#                 UC2_Literal       neighborhood        lat       long  \
# 0      LARCENY-FROM VEHICLE         Hills Park  33.801693 -84.436453
# 1      LARCENY-FROM VEHICLE           Downtown  33.762549 -84.387874
# 2      LARCENY-FROM VEHICLE           Downtown  33.760759 -84.383773
# 3       LARCENY-NON VEHICLE          Vine City  33.755768 -84.416631
# 4      LARCENY-FROM VEHICLE           West End  33.740594 -84.415800
# ...                     ...                ...        ...        ...
# 14080              BURGLARY       Oakland City  33.724966 -84.426435
# 14081   LARCENY-NON VEHICLE  Virginia Highland  33.779969 -84.349806
# 14082              BURGLARY       Sweet Auburn  33.750784 -84.376964
# 14083  LARCENY-FROM VEHICLE       Sweet Auburn  33.759313 -84.375614
# 14084   LARCENY-NON VEHICLE        Peoplestown  33.723348 -84.393203
#
#                          Address        Country     city state  zipcode
# 0        1720 MARIETTA BLVD NW\r  UNITED STATES  Atlanta    GA  30318\r
# 1          300 PEACHTREE ST NE\r  UNITED STATES  Atlanta    GA  30308\r
# 2          229 COURTLAND ST NE\r  UNITED STATES  Atlanta    GA  30303\r
# 3      870 MAYSON TURNER RD NW\r  UNITED STATES  Atlanta    GA  30314\r
# 4                850 OAK ST SW\r  UNITED STATES  Atlanta    GA  30310\r
# ...                          ...            ...      ...   ...      ...
# 14080       1099 SELWIN AVE SW\r  UNITED STATES  Atlanta    GA  30310\r
# 14081      1144 ROSEDALE DR NE\r  UNITED STATES  Atlanta    GA  30306\r
# 14082       141 HILLIARD ST SE\r  UNITED STATES  Atlanta    GA  30312\r
# 14083        180 JACKSON ST NE\r  UNITED STATES  Atlanta    GA  30312\r
# 14084         1162 PRYOR ST SW\r  UNITED STATES  Atlanta    GA  30315\r
#
# [26076 rows x 16 columns]

# %%
new_crime['zipcode'] = new_crime['zipcode'].str.split("\r").str[0]
new_crime
# Out:
# C:\Users\vinoy\anaconda3\envs\Pythondata\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        offense_id   rpt_date occur_date occur_time  poss_date poss_time  beat  \
# 0        21140096  5/20/2021  5/19/2021      15:20  5/19/2021     15:25   103
# 1        21282015   8/6/2021   8/6/2021      22:23   8/6/2021     22:24   508
# 2        21320347   2/1/2021  1/31/2021      00:00   2/1/2021     06:53   509
# 3        21791668  6/28/2021  6/27/2021      21:17  6/28/2021     20:00   102
# 4        61583880  2/11/2021  2/11/2021      19:15  2/11/2021     20:29   401
# ...           ...        ...        ...        ...        ...       ...   ...
# 14080   212230459  8/11/2021  8/10/2021      19:30  8/11/2021     07:30   403
# 14081   212230498  8/11/2021   8/2/2021      14:30   8/2/2021     16:00   601
# 14082   212230549  8/11/2021  8/11/2021      09:21  8/11/2021     09:28   604
# 14083   212230568  8/11/2021  8/10/2021      21:40  8/11/2021     09:26   604
# 14084   212230651  8/11/2021  8/11/2021      09:00  8/11/2021     10:58   304
#
#                 UC2_Literal       neighborhood        lat       long  \
# 0      LARCENY-FROM VEHICLE         Hills Park  33.801693 -84.436453
# 1      LARCENY-FROM VEHICLE           Downtown  33.762549 -84.387874
# 2      LARCENY-FROM VEHICLE           Downtown  33.760759 -84.383773
# 3       LARCENY-NON VEHICLE          Vine City  33.755768 -84.416631
# 4      LARCENY-FROM VEHICLE           West End  33.740594 -84.415800
# ...                     ...                ...        ...        ...
# 14080              BURGLARY       Oakland City  33.724966 -84.426435
# 14081   LARCENY-NON VEHICLE  Virginia Highland  33.779969 -84.349806
# 14082              BURGLARY       Sweet Auburn  33.750784 -84.376964
# 14083  LARCENY-FROM VEHICLE       Sweet Auburn  33.759313 -84.375614
# 14084   LARCENY-NON VEHICLE        Peoplestown  33.723348 -84.393203
#
#                          Address        Country     city state zipcode
# 0        1720 MARIETTA BLVD NW\r  UNITED STATES  Atlanta    GA   30318
# 1          300 PEACHTREE ST NE\r  UNITED STATES  Atlanta    GA   30308
# 2          229 COURTLAND ST NE\r  UNITED STATES  Atlanta    GA   30303
# 3      870 MAYSON TURNER RD NW\r  UNITED STATES  Atlanta    GA   30314
# 4                850 OAK ST SW\r  UNITED STATES  Atlanta    GA   30310
# ...                          ...            ...      ...   ...     ...
# 14080       1099 SELWIN AVE SW\r  UNITED STATES  Atlanta    GA   30310
# 14081      1144 ROSEDALE DR NE\r  UNITED STATES  Atlanta    GA   30306
# 14082       141 HILLIARD ST SE\r  UNITED STATES  Atlanta    GA   30312
# 14083        180 JACKSON ST NE\r  UNITED STATES  Atlanta    GA   30312
# 14084         1162 PRYOR ST SW\r  UNITED STATES  Atlanta    GA   30315
#
# [26076 rows x 16 columns]

# %%
new_crime.dropna(how='any', inplace = True)
new_crime
# Out:
# C:\Users\vinoy\anaconda3\envs\Pythondata\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        offense_id   rpt_date occur_date occur_time  poss_date poss_time  beat  \
# 0        21140096  5/20/2021  5/19/2021      15:20  5/19/2021     15:25   103
# 1        21282015   8/6/2021   8/6/2021      22:23   8/6/2021     22:24   508
# 2        21320347   2/1/2021  1/31/2021      00:00   2/1/2021     06:53   509
# 3        21791668  6/28/2021  6/27/2021      21:17  6/28/2021     20:00   102
# 4        61583880  2/11/2021  2/11/2021      19:15  2/11/2021     20:29   401
# ...           ...        ...        ...        ...        ...       ...   ...
# 14080   212230459  8/11/2021  8/10/2021      19:30  8/11/2021     07:30   403
# 14081   212230498  8/11/2021   8/2/2021      14:30   8/2/2021     16:00   601
# 14082   212230549  8/11/2021  8/11/2021      09:21  8/11/2021     09:28   604
# 14083   212230568  8/11/2021  8/10/2021      21:40  8/11/2021     09:26   604
# 14084   212230651  8/11/2021  8/11/2021      09:00  8/11/2021     10:58   304
#
#                 UC2_Literal       neighborhood        lat       long  \
# 0      LARCENY-FROM VEHICLE         Hills Park  33.801693 -84.436453
# 1      LARCENY-FROM VEHICLE           Downtown  33.762549 -84.387874
# 2      LARCENY-FROM VEHICLE           Downtown  33.760759 -84.383773
# 3       LARCENY-NON VEHICLE          Vine City  33.755768 -84.416631
# 4      LARCENY-FROM VEHICLE           West End  33.740594 -84.415800
# ...                     ...                ...        ...        ...
# 14080              BURGLARY       Oakland City  33.724966 -84.426435
# 14081   LARCENY-NON VEHICLE  Virginia Highland  33.779969 -84.349806
# 14082              BURGLARY       Sweet Auburn  33.750784 -84.376964
# 14083  LARCENY-FROM VEHICLE       Sweet Auburn  33.759313 -84.375614
# 14084   LARCENY-NON VEHICLE        Peoplestown  33.723348 -84.393203
#
#                          Address        Country     city state zipcode
# 0        1720 MARIETTA BLVD NW\r  UNITED STATES  Atlanta    GA   30318
# 1          300 PEACHTREE ST NE\r  UNITED STATES  Atlanta    GA   30308
# 2          229 COURTLAND ST NE\r  UNITED STATES  Atlanta    GA   30303
# 3      870 MAYSON TURNER RD NW\r  UNITED STATES  Atlanta    GA   30314
# 4                850 OAK ST SW\r  UNITED STATES  Atlanta    GA   30310
# ...                          ...            ...      ...   ...     ...
# 14080       1099 SELWIN AVE SW\r  UNITED STATES  Atlanta    GA   30310
# 14081      1144 ROSEDALE DR NE\r  UNITED STATES  Atlanta    GA   30306
# 14082       141 HILLIARD ST SE\r  UNITED STATES  Atlanta    GA   30312
# 14083        180 JACKSON ST NE\r  UNITED STATES  Atlanta    GA   30312
# 14084         1162 PRYOR ST SW\r  UNITED STATES  Atlanta    GA   30315
#
# [25990 rows x 16 columns]

# %%
new_crime["zipcode"].value_counts()
# Out:
# 30318    3418
# 30310    1958
# 30309    1910
# 30308    1792
# 30315    1784
# 30312    1662
# 30303    1600
# 30324    1542
# 30305    1344
# 30314    1228
# 30331    1186
# 30313    1098
# 30311    1020
# 30307     830
# 30316     746
# 30306     720
# 30326     672
# 30354     392
# 30317     314
# 30363     238
# 30327     206
# 30342     204
# 30319      72
# 30344      22
# 30336       8
# 30361       8
# 30328       6
# 30339       4
# 30375       2
# 30380       2
# 30304       2
# Name: zipcode, dtype: int64

# %%
clean_new_crime = new_crime.drop(columns=['occur_date','occur_time','Address','Country','city','state'])
clean_new_crime
# Out:
#        offense_id   rpt_date  poss_date poss_time  beat           UC2_Literal  \
# 0        21140096  5/20/2021  5/19/2021     15:25   103  LARCENY-FROM VEHICLE
# 1        21282015   8/6/2021   8/6/2021     22:24   508  LARCENY-FROM VEHICLE
# 2        21320347   2/1/2021   2/1/2021     06:53   509  LARCENY-FROM VEHICLE
# 3        21791668  6/28/2021  6/28/2021     20:00   102   LARCENY-NON VEHICLE
# 4        61583880  2/11/2021  2/11/2021     20:29   401  LARCENY-FROM VEHICLE
# ...           ...        ...        ...       ...   ...                   ...
# 14080   212230459  8/11/2021  8/11/2021     07:30   403              BURGLARY
# 14081   212230498  8/11/2021   8/2/2021     16:00   601   LARCENY-NON VEHICLE
# 14082   212230549  8/11/2021  8/11/2021     09:28   604              BURGLARY
# 14083   212230568  8/11/2021  8/11/2021     09:26   604  LARCENY-FROM VEHICLE
# 14084   212230651  8/11/2021  8/11/2021     10:58   304   LARCENY-NON VEHICLE
#
#             neighborhood        lat       long zipcode
# 0             Hills Park  33.801693 -84.436453   30318
# 1               Downtown  33.762549 -84.387874   30308
# 2               Downtown  33.760759 -84.383773   30303
# 3              Vine City  33.755768 -84.416631   30314
# 4               West End  33.740594 -84.415800   30310
# ...                  ...        ...        ...     ...
# 14080       Oakland City  33.724966 -84.426435   30310
# 14081  Virginia Highland  33.779969 -84.349806   30306
# 14082       Sweet Auburn  33.750784 -84.376964   30312
# 14083       Sweet Auburn  33.759313 -84.375614   30312
# 14084        Peoplestown  33.723348 -84.393203   30315
#
# [25990 rows x 10 columns]

# %%
new_crime["poss_date"].value_counts()
# Out:
# 3/7/2021      216
# 1/25/2021     212
# 1/24/2021     192
# 1/23/2021     186
# 1/2/2021      176
#              ...
# 12/12/2021      2
# 9/21/2020       2
# 2/1/2020        2
# 10/31/2020      2
# 6/10/1800       2
# Name: poss_date, Length: 258, dtype: int64

# %%
clean_new_crime.to_csv("crime_20-21.csv", encoding='utf-8', index= False)

# %%
clean_new_crime.dtypes
# Out:
# offense_id        int64
# rpt_date         object
# poss_date        object
# poss_time        object
# beat              int64
# UC2_Literal      object
# neighborhood     object
# lat             float64
# long            float64
# zipcode          object
# dtype: object

# %%
data10 = pd.read_csv("../raw_data/COBRA-2009-2019_fixed.csv")
data10
# Out:
# C:\Users\vinoy\anaconda3\envs\Pythondata\lib\site-packages\IPython\core\interactiveshell.py:3072: DtypeWarning: Columns (13) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         Report Number Report Date  Occur Date  Occur Time Occur time (fixed)  \
# 0            90010930   1,01,2009   1,01,2009        1145              11:45
# 1            90011083   1,01,2009   1,01,2009        1330              13:30
# 2            90011208   1,01,2009   1,01,2009        1500              15:00
# 3            90011218   1,01,2009   1,01,2009        1450              14:50
# 4            90011289   1,01,2009   1,01,2009        1600              16:00
# ...               ...         ...         ...         ...                ...
# 342908      193652089  12,31,2019  12,31,2019        2030              20:30
# 342909      193650336  12,31,2019  12,31,2019         432               4:32
# 342910      193650603  12,31,2019  12,31,2019         920               9:20
# 342911      193651760  12,31,2019  12,31,2019        1853              18:53
# 342912      193652591  12,31,2019  12,31,2019        2045              20:45
#
#        Possible Date  Possible Time Possible time (fixed)   Beat  \
# 0          1,01,2009         1148.0              11:48:00  411.0
# 1          1,01,2009         1330.0              13:30:00  511.0
# 2          1,01,2009         1520.0              15:20:00  407.0
# 3          1,01,2009         1510.0              15:10:00  210.0
# 4          1,01,2009         1700.0              17:00:00  411.0
# ...              ...            ...                   ...    ...
# 342908    12,31,2019         2034.0              20:34:00  105.0
# 342909    12,31,2019          432.0               4:32:00  206.0
# 342910    12,31,2019          940.0               9:40:00  404.0
# 342911    12,31,2019         1900.0              19:00:00  404.0
# 342912    12,31,2019         2055.0              20:55:00  406.0
#
#        Apartment Office Prefix  ...                     Location  \
# 0                          NaN  ...         2841 GREENBRIAR PKWY
# 1                          NaN  ...               12 BROAD ST SW
# 2                          NaN  ...  3500 MARTIN L KING JR DR SW
# 3                          NaN  ...         3393 PEACHTREE RD NE
# 4                          NaN  ...      2841 GREENBRIAR PKWY SW
# ...                        ...  ...                          ...
# 342908                     NaN  ...            1385 SHARON ST NW
# 342909                     NaN  ...              262 PHARR RD NE
# 342910                     NaN  ...           689 CASCADE AVE SW
# 342911                     NaN  ...           763 CASCADE AVE SW
# 342912                     NaN  ...             237 PEYTON PL SW
#
#        Shift Occurence Location Type          UCR Literal UCR #  IBR Code  \
# 0            Day Watch             8  LARCENY-NON VEHICLE   630      2303
# 1            Day Watch             9  LARCENY-NON VEHICLE   630      2303
# 2              Unknown             8  LARCENY-NON VEHICLE   630      2303
# 3        Evening Watch             8  LARCENY-NON VEHICLE   630      2303
# 4              Unknown             8  LARCENY-NON VEHICLE   630      2303
# ...                ...           ...                  ...   ...       ...
# 342908   Morning Watch            20          AGG ASSAULT   420     1315K
# 342909   Morning Watch           NaN          AGG ASSAULT   410      1314
# 342910       Day Watch            18          AGG ASSAULT   410      1314
# 342911   Evening Watch            26          AGG ASSAULT   410      1314
# 342912   Evening Watch            20          AGG ASSAULT   410      1314
#
#                Neighborhood NPU  Latitude  Longitude
# 0                Greenbriar   R  33.68845  -84.49328
# 1                  Downtown   M  33.75320  -84.39201
# 2                Adamsville   H  33.75735  -84.50282
# 3                     Lenox   B  33.84676  -84.36212
# 4                Greenbriar   R  33.68677  -84.49773
# ...                     ...  ..       ...        ...
# 342908         Hunter Hills   K  33.75486  -84.43287
# 342909     Buckhead Village   B  33.83732  -84.37860
# 342910             Westview   T  33.73636  -84.43680
# 342911             Westview   T  33.73483  -84.43750
# 342912  Cascade Avenue/Road   S  33.72518  -84.45013
#
# [342913 rows x 21 columns]

# %%
data10.dtypes
# Out:
# Report Number                int64
# Report Date                 object
# Occur Date                  object
# Occur Time                   int64
# Occur time (fixed)          object
# Possible Date               object
# Possible Time              float64
# Possible time (fixed)       object
# Beat                       float64
# Apartment Office Prefix     object
# Apartment Number            object
# Location                    object
# Shift Occurence             object
# Location Type               object
# UCR Literal                 object
# UCR #                        int64
# IBR Code                    object
# Neighborhood                object
# NPU                         object
# Latitude                   float64
# Longitude                  float64
# dtype: object

# %%
crime10 = data10.drop(columns=['Location Type','Apartment Office Prefix','Apartment Number','IBR Code','NPU','Shift Occurence'])
crime10
# Out:
#         Report Number Report Date  Occur Date  Occur Time Occur time (fixed)  \
# 0            90010930   1,01,2009   1,01,2009        1145              11:45
# 1            90011083   1,01,2009   1,01,2009        1330              13:30
# 2            90011208   1,01,2009   1,01,2009        1500              15:00
# 3            90011218   1,01,2009   1,01,2009        1450              14:50
# 4            90011289   1,01,2009   1,01,2009        1600              16:00
# ...               ...         ...         ...         ...                ...
# 342908      193652089  12,31,2019  12,31,2019        2030              20:30
# 342909      193650336  12,31,2019  12,31,2019         432               4:32
# 342910      193650603  12,31,2019  12,31,2019         920               9:20
# 342911      193651760  12,31,2019  12,31,2019        1853              18:53
# 342912      193652591  12,31,2019  12,31,2019        2045              20:45
#
#        Possible Date  Possible Time Possible time (fixed)   Beat  \
# 0          1,01,2009         1148.0              11:48:00  411.0
# 1          1,01,2009         1330.0              13:30:00  511.0
# 2          1,01,2009         1520.0              15:20:00  407.0
# 3          1,01,2009         1510.0              15:10:00  210.0
# 4          1,01,2009         1700.0              17:00:00  411.0
# ...              ...            ...                   ...    ...
# 342908    12,31,2019         2034.0              20:34:00  105.0
# 342909    12,31,2019          432.0               4:32:00  206.0
# 342910    12,31,2019          940.0               9:40:00  404.0
# 342911    12,31,2019         1900.0              19:00:00  404.0
# 342912    12,31,2019         2055.0              20:55:00  406.0
#
#                            Location          UCR Literal  UCR #  \
# 0              2841 GREENBRIAR PKWY  LARCENY-NON VEHICLE    630
# 1                    12 BROAD ST SW  LARCENY-NON VEHICLE    630
# 2       3500 MARTIN L KING JR DR SW  LARCENY-NON VEHICLE    630
# 3              3393 PEACHTREE RD NE  LARCENY-NON VEHICLE    630
# 4           2841 GREENBRIAR PKWY SW  LARCENY-NON VEHICLE    630
# ...                             ...                  ...    ...
# 342908            1385 SHARON ST NW          AGG ASSAULT    420
# 342909              262 PHARR RD NE          AGG ASSAULT    410
# 342910           689 CASCADE AVE SW          AGG ASSAULT    410
# 342911           763 CASCADE AVE SW          AGG ASSAULT    410
# 342912             237 PEYTON PL SW          AGG ASSAULT    410
#
#                Neighborhood  Latitude  Longitude
# 0                Greenbriar  33.68845  -84.49328
# 1                  Downtown  33.75320  -84.39201
# 2                Adamsville  33.75735  -84.50282
# 3                     Lenox  33.84676  -84.36212
# 4                Greenbriar  33.68677  -84.49773
# ...                     ...       ...        ...
# 342908         Hunter Hills  33.75486  -84.43287
# 342909     Buckhead Village  33.83732  -84.37860
# 342910             Westview  33.73636  -84.43680
# 342911             Westview  33.73483  -84.43750
# 342912  Cascade Avenue/Road  33.72518  -84.45013
#
# [342913 rows x 15 columns]

# %%
crime10.dropna(how='any', inplace = True)
crime10
# Out:
#         Report Number Report Date  Occur Date  Occur Time Occur time (fixed)  \
# 0            90010930   1,01,2009   1,01,2009        1145              11:45
# 1            90011083   1,01,2009   1,01,2009        1330              13:30
# 2            90011208   1,01,2009   1,01,2009        1500              15:00
# 3            90011218   1,01,2009   1,01,2009        1450              14:50
# 4            90011289   1,01,2009   1,01,2009        1600              16:00
# ...               ...         ...         ...         ...                ...
# 342908      193652089  12,31,2019  12,31,2019        2030              20:30
# 342909      193650336  12,31,2019  12,31,2019         432               4:32
# 342910      193650603  12,31,2019  12,31,2019         920               9:20
# 342911      193651760  12,31,2019  12,31,2019        1853              18:53
# 342912      193652591  12,31,2019  12,31,2019        2045              20:45
#
#        Possible Date  Possible Time Possible time (fixed)   Beat  \
# 0          1,01,2009         1148.0              11:48:00  411.0
# 1          1,01,2009         1330.0              13:30:00  511.0
# 2          1,01,2009         1520.0              15:20:00  407.0
# 3          1,01,2009         1510.0              15:10:00  210.0
# 4          1,01,2009         1700.0              17:00:00  411.0
# ...              ...            ...                   ...    ...
# 342908    12,31,2019         2034.0              20:34:00  105.0
# 342909    12,31,2019          432.0               4:32:00  206.0
# 342910    12,31,2019          940.0               9:40:00  404.0
# 342911    12,31,2019         1900.0              19:00:00  404.0
# 342912    12,31,2019         2055.0              20:55:00  406.0
#
#                            Location          UCR Literal  UCR #  \
# 0              2841 GREENBRIAR PKWY  LARCENY-NON VEHICLE    630
# 1                    12 BROAD ST SW  LARCENY-NON VEHICLE    630
# 2       3500 MARTIN L KING JR DR SW  LARCENY-NON VEHICLE    630
# 3              3393 PEACHTREE RD NE  LARCENY-NON VEHICLE    630
# 4           2841 GREENBRIAR PKWY SW  LARCENY-NON VEHICLE    630
# ...                             ...                  ...    ...
# 342908            1385 SHARON ST NW          AGG ASSAULT    420
# 342909              262 PHARR RD NE          AGG ASSAULT    410
# 342910           689 CASCADE AVE SW          AGG ASSAULT    410
# 342911           763 CASCADE AVE SW          AGG ASSAULT    410
# 342912             237 PEYTON PL SW          AGG ASSAULT    410
#
#                Neighborhood  Latitude  Longitude
# 0                Greenbriar  33.68845  -84.49328
# 1                  Downtown  33.75320  -84.39201
# 2                Adamsville  33.75735  -84.50282
# 3                     Lenox  33.84676  -84.36212
# 4                Greenbriar  33.68677  -84.49773
# ...                     ...       ...        ...
# 342908         Hunter Hills  33.75486  -84.43287
# 342909     Buckhead Village  33.83732  -84.37860
# 342910             Westview  33.73636  -84.43680
# 342911             Westview  33.73483  -84.43750
# 342912  Cascade Avenue/Road  33.72518  -84.45013
#
# [330486 rows x 15 columns]

# %%
crime10 = crime10.loc[(crime10['Possible time (fixed)'] != "#VALUE!")]
crime10
# Out:
#         Report Number Report Date  Occur Date  Occur Time Occur time (fixed)  \
# 0            90010930   1,01,2009   1,01,2009        1145              11:45
# 1            90011083   1,01,2009   1,01,2009        1330              13:30
# 2            90011208   1,01,2009   1,01,2009        1500              15:00
# 3            90011218   1,01,2009   1,01,2009        1450              14:50
# 4            90011289   1,01,2009   1,01,2009        1600              16:00
# ...               ...         ...         ...         ...                ...
# 342908      193652089  12,31,2019  12,31,2019        2030              20:30
# 342909      193650336  12,31,2019  12,31,2019         432               4:32
# 342910      193650603  12,31,2019  12,31,2019         920               9:20
# 342911      193651760  12,31,2019  12,31,2019        1853              18:53
# 342912      193652591  12,31,2019  12,31,2019        2045              20:45
#
#        Possible Date  Possible Time Possible time (fixed)   Beat  \
# 0          1,01,2009         1148.0              11:48:00  411.0
# 1          1,01,2009         1330.0              13:30:00  511.0
# 2          1,01,2009         1520.0              15:20:00  407.0
# 3          1,01,2009         1510.0              15:10:00  210.0
# 4          1,01,2009         1700.0              17:00:00  411.0
# ...              ...            ...                   ...    ...
# 342908    12,31,2019         2034.0              20:34:00  105.0
# 342909    12,31,2019          432.0               4:32:00  206.0
# 342910    12,31,2019          940.0               9:40:00  404.0
# 342911    12,31,2019         1900.0              19:00:00  404.0
# 342912    12,31,2019         2055.0              20:55:00  406.0
#
#                            Location          UCR Literal  UCR #  \
# 0              2841 GREENBRIAR PKWY  LARCENY-NON VEHICLE    630
# 1                    12 BROAD ST SW  LARCENY-NON VEHICLE    630
# 2       3500 MARTIN L KING JR DR SW  LARCENY-NON VEHICLE    630
# 3              3393 PEACHTREE RD NE  LARCENY-NON VEHICLE    630
# 4           2841 GREENBRIAR PKWY SW  LARCENY-NON VEHICLE    630
# ...                             ...                  ...    ...
# 342908            1385 SHARON ST NW          AGG ASSAULT    420
# 342909              262 PHARR RD NE          AGG ASSAULT    410
# 342910           689 CASCADE AVE SW          AGG ASSAULT    410
# 342911           763 CASCADE AVE SW          AGG ASSAULT    410
# 342912             237 PEYTON PL SW          AGG ASSAULT    410
#
#                Neighborhood  Latitude  Longitude
# 0                Greenbriar  33.68845  -84.49328
# 1                  Downtown  33.75320  -84.39201
# 2                Adamsville  33.75735  -84.50282
# 3                     Lenox  33.84676  -84.36212
# 4                Greenbriar  33.68677  -84.49773
# ...                     ...       ...        ...
# 342908         Hunter Hills  33.75486  -84.43287
# 342909     Buckhead Village  33.83732  -84.37860
# 342910             Westview  33.73636  -84.43680
# 342911             Westview  33.73483  -84.43750
# 342912  Cascade Avenue/Road  33.72518  -84.45013
#
# [319650 rows x 15 columns]

# %%
crime10['Possible Date New'] =  pd.to_datetime(crime10['Possible Date'], format ='%m,%d,%Y')
crime10
# Out:
# C:\Users\vinoy\anaconda3\envs\Pythondata\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#         Report Number Report Date  Occur Date  Occur Time Occur time (fixed)  \
# 0            90010930   1,01,2009   1,01,2009        1145              11:45
# 1            90011083   1,01,2009   1,01,2009        1330              13:30
# 2            90011208   1,01,2009   1,01,2009        1500              15:00
# 3            90011218   1,01,2009   1,01,2009        1450              14:50
# 4            90011289   1,01,2009   1,01,2009        1600              16:00
# ...               ...         ...         ...         ...                ...
# 342908      193652089  12,31,2019  12,31,2019        2030              20:30
# 342909      193650336  12,31,2019  12,31,2019         432               4:32
# 342910      193650603  12,31,2019  12,31,2019         920               9:20
# 342911      193651760  12,31,2019  12,31,2019        1853              18:53
# 342912      193652591  12,31,2019  12,31,2019        2045              20:45
#
#        Possible Date  Possible Time Possible time (fixed)   Beat  \
# 0          1,01,2009         1148.0              11:48:00  411.0
# 1          1,01,2009         1330.0              13:30:00  511.0
# 2          1,01,2009         1520.0              15:20:00  407.0
# 3          1,01,2009         1510.0              15:10:00  210.0
# 4          1,01,2009         1700.0              17:00:00  411.0
# ...              ...            ...                   ...    ...
# 342908    12,31,2019         2034.0              20:34:00  105.0
# 342909    12,31,2019          432.0               4:32:00  206.0
# 342910    12,31,2019          940.0               9:40:00  404.0
# 342911    12,31,2019         1900.0              19:00:00  404.0
# 342912    12,31,2019         2055.0              20:55:00  406.0
#
#                            Location          UCR Literal  UCR #  \
# 0              2841 GREENBRIAR PKWY  LARCENY-NON VEHICLE    630
# 1                    12 BROAD ST SW  LARCENY-NON VEHICLE    630
# 2       3500 MARTIN L KING JR DR SW  LARCENY-NON VEHICLE    630
# 3              3393 PEACHTREE RD NE  LARCENY-NON VEHICLE    630
# 4           2841 GREENBRIAR PKWY SW  LARCENY-NON VEHICLE    630
# ...                             ...                  ...    ...
# 342908            1385 SHARON ST NW          AGG ASSAULT    420
# 342909              262 PHARR RD NE          AGG ASSAULT    410
# 342910           689 CASCADE AVE SW          AGG ASSAULT    410
# 342911           763 CASCADE AVE SW          AGG ASSAULT    410
# 342912             237 PEYTON PL SW          AGG ASSAULT    410
#
#                Neighborhood  Latitude  Longitude Possible Date New
# 0                Greenbriar  33.68845  -84.49328        2009-01-01
# 1                  Downtown  33.75320  -84.39201        2009-01-01
# 2                Adamsville  33.75735  -84.50282        2009-01-01
# 3                     Lenox  33.84676  -84.36212        2009-01-01
# 4                Greenbriar  33.68677  -84.49773        2009-01-01
# ...                     ...       ...        ...               ...
# 342908         Hunter Hills  33.75486  -84.43287        2019-12-31
# 342909     Buckhead Village  33.83732  -84.37860        2019-12-31
# 342910             Westview  33.73636  -84.43680        2019-12-31
# 342911             Westview  33.73483  -84.43750        2019-12-31
# 342912  Cascade Avenue/Road  33.72518  -84.45013        2019-12-31
#
# [319650 rows x 16 columns]

# %%
crime10.dtypes
# Out:
# Report Number                     int64
# Report Date                      object
# Occur Date                       object
# Occur Time                        int64
# Occur time (fixed)               object
# Possible Date                    object
# Possible Time                   float64
# Possible time (fixed)            object
# Beat                            float64
# Location                         object
# UCR Literal                      object
# UCR #                             int64
# Neighborhood                     object
# Latitude                        float64
# Longitude                       float64
# Possible Date New        datetime64[ns]
# dtype: object

# %%
crime10['Poss YEAR'] = pd.DatetimeIndex(crime10['Possible Date New']).year
crime10
# Out:
# C:\Users\vinoy\anaconda3\envs\Pythondata\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#         Report Number Report Date  Occur Date  Occur Time Occur time (fixed)  \
# 0            90010930   1,01,2009   1,01,2009        1145              11:45
# 1            90011083   1,01,2009   1,01,2009        1330              13:30
# 2            90011208   1,01,2009   1,01,2009        1500              15:00
# 3            90011218   1,01,2009   1,01,2009        1450              14:50
# 4            90011289   1,01,2009   1,01,2009        1600              16:00
# ...               ...         ...         ...         ...                ...
# 342908      193652089  12,31,2019  12,31,2019        2030              20:30
# 342909      193650336  12,31,2019  12,31,2019         432               4:32
# 342910      193650603  12,31,2019  12,31,2019         920               9:20
# 342911      193651760  12,31,2019  12,31,2019        1853              18:53
# 342912      193652591  12,31,2019  12,31,2019        2045              20:45
#
#        Possible Date  Possible Time Possible time (fixed)   Beat  \
# 0          1,01,2009         1148.0              11:48:00  411.0
# 1          1,01,2009         1330.0              13:30:00  511.0
# 2          1,01,2009         1520.0              15:20:00  407.0
# 3          1,01,2009         1510.0              15:10:00  210.0
# 4          1,01,2009         1700.0              17:00:00  411.0
# ...              ...            ...                   ...    ...
# 342908    12,31,2019         2034.0              20:34:00  105.0
# 342909    12,31,2019          432.0               4:32:00  206.0
# 342910    12,31,2019          940.0               9:40:00  404.0
# 342911    12,31,2019         1900.0              19:00:00  404.0
# 342912    12,31,2019         2055.0              20:55:00  406.0
#
#                            Location          UCR Literal  UCR #  \
# 0              2841 GREENBRIAR PKWY  LARCENY-NON VEHICLE    630
# 1                    12 BROAD ST SW  LARCENY-NON VEHICLE    630
# 2       3500 MARTIN L KING JR DR SW  LARCENY-NON VEHICLE    630
# 3              3393 PEACHTREE RD NE  LARCENY-NON VEHICLE    630
# 4           2841 GREENBRIAR PKWY SW  LARCENY-NON VEHICLE    630
# ...                             ...                  ...    ...
# 342908            1385 SHARON ST NW          AGG ASSAULT    420
# 342909              262 PHARR RD NE          AGG ASSAULT    410
# 342910           689 CASCADE AVE SW          AGG ASSAULT    410
# 342911           763 CASCADE AVE SW          AGG ASSAULT    410
# 342912             237 PEYTON PL SW          AGG ASSAULT    410
#
#                Neighborhood  Latitude  Longitude Possible Date New  Poss YEAR
# 0                Greenbriar  33.68845  -84.49328        2009-01-01       2009
# 1                  Downtown  33.75320  -84.39201        2009-01-01       2009
# 2                Adamsville  33.75735  -84.50282        2009-01-01       2009
# 3                     Lenox  33.84676  -84.36212        2009-01-01       2009
# 4                Greenbriar  33.68677  -84.49773        2009-01-01       2009
# ...                     ...       ...        ...               ...        ...
# 342908         Hunter Hills  33.75486  -84.43287        2019-12-31       2019
# 342909     Buckhead Village  33.83732  -84.37860        2019-12-31       2019
# 342910             Westview  33.73636  -84.43680        2019-12-31       2019
# 342911             Westview  33.73483  -84.43750        2019-12-31       2019
# 342912  Cascade Avenue/Road  33.72518  -84.45013        2019-12-31       2019
#
# [319650 rows x 17 columns]

# %%
crime10 = crime10.loc[(crime10['Poss YEAR'] >= 2009 ) & (crime10['Poss YEAR'] <2020 ) ]
crime10.head(2)
# Out:
#    Report Number Report Date Occur Date  Occur Time Occur time (fixed)  \
# 0       90010930   1,01,2009  1,01,2009        1145              11:45
# 1       90011083   1,01,2009  1,01,2009        1330              13:30
#
#   Possible Date  Possible Time Possible time (fixed)   Beat  \
# 0     1,01,2009         1148.0              11:48:00  411.0
# 1     1,01,2009         1330.0              13:30:00  511.0
#
#                Location          UCR Literal  UCR # Neighborhood  Latitude  \
# 0  2841 GREENBRIAR PKWY  LARCENY-NON VEHICLE    630   Greenbriar  33.68845
# 1        12 BROAD ST SW  LARCENY-NON VEHICLE    630     Downtown  33.75320
#
#    Longitude Possible Date New  Poss YEAR
# 0  -84.49328        2009-01-01       2009
# 1  -84.39201        2009-01-01       2009

# %%
crime10["Poss YEAR"].value_counts()
# Out:
# 2009    36854
# 2010    33221
# 2011    32484
# 2012    31054
# 2013    30329
# 2014    29149
# 2015    27917
# 2016    26894
# 2017    24610
# 2018    23912
# 2019    23113
# Name: Poss YEAR, dtype: int64

# %%
clean_crime10 = crime10.drop(columns=['Occur Date','Occur Time','Occur time (fixed)','Possible Date','Possible Time'])
clean_crime10
# Out:
#         Report Number Report Date Possible time (fixed)   Beat  \
# 0            90010930   1,01,2009              11:48:00  411.0
# 1            90011083   1,01,2009              13:30:00  511.0
# 2            90011208   1,01,2009              15:20:00  407.0
# 3            90011218   1,01,2009              15:10:00  210.0
# 4            90011289   1,01,2009              17:00:00  411.0
# ...               ...         ...                   ...    ...
# 342908      193652089  12,31,2019              20:34:00  105.0
# 342909      193650336  12,31,2019               4:32:00  206.0
# 342910      193650603  12,31,2019               9:40:00  404.0
# 342911      193651760  12,31,2019              19:00:00  404.0
# 342912      193652591  12,31,2019              20:55:00  406.0
#
#                            Location          UCR Literal  UCR #  \
# 0              2841 GREENBRIAR PKWY  LARCENY-NON VEHICLE    630
# 1                    12 BROAD ST SW  LARCENY-NON VEHICLE    630
# 2       3500 MARTIN L KING JR DR SW  LARCENY-NON VEHICLE    630
# 3              3393 PEACHTREE RD NE  LARCENY-NON VEHICLE    630
# 4           2841 GREENBRIAR PKWY SW  LARCENY-NON VEHICLE    630
# ...                             ...                  ...    ...
# 342908            1385 SHARON ST NW          AGG ASSAULT    420
# 342909              262 PHARR RD NE          AGG ASSAULT    410
# 342910           689 CASCADE AVE SW          AGG ASSAULT    410
# 342911           763 CASCADE AVE SW          AGG ASSAULT    410
# 342912             237 PEYTON PL SW          AGG ASSAULT    410
#
#                Neighborhood  Latitude  Longitude Possible Date New  Poss YEAR
# 0                Greenbriar  33.68845  -84.49328        2009-01-01       2009
# 1                  Downtown  33.75320  -84.39201        2009-01-01       2009
# 2                Adamsville  33.75735  -84.50282        2009-01-01       2009
# 3                     Lenox  33.84676  -84.36212        2009-01-01       2009
# 4                Greenbriar  33.68677  -84.49773        2009-01-01       2009
# ...                     ...       ...        ...               ...        ...
# 342908         Hunter Hills  33.75486  -84.43287        2019-12-31       2019
# 342909     Buckhead Village  33.83732  -84.37860        2019-12-31       2019
# 342910             Westview  33.73636  -84.43680        2019-12-31       2019
# 342911             Westview  33.73483  -84.43750        2019-12-31       2019
# 342912  Cascade Avenue/Road  33.72518  -84.45013        2019-12-31       2019
#
# [319537 rows x 12 columns]

# %%
clean_crime10.rename(columns={"Possible time (fixed)": "Poss Time"},inplace = True)

# %%
clean_crime10.to_csv("crime_new-2009-2019.csv", encoding='utf-8', index= False)

# %%
clean_crime10.dtypes
# Out:
# Report Number                 int64
# Report Date                  object
# Poss Time                    object
# Beat                        float64
# Location                     object
# UCR Literal                  object
# UCR #                         int64
# Neighborhood                 object
# Latitude                    float64
# Longitude                   float64
# Possible Date New    datetime64[ns]
# Poss YEAR                     int64
# dtype: object

# %%
crime_zip = pd.read_csv("../raw_data/crime_new-2009-2019_addzip.csv")

# %%
crime_zip = crime_zip.drop(columns=['Occur Date','Occur Time','Occur time (fixed)','Possible Date','Possible Time'])
crime_zip.rename(columns={"Possible time (fixed)": "Poss Time"},inplace = True)
crime_zip
# Out:
#         Report Number Report Date Poss Time  Beat  \
# 0            90010930   1,01,2009  11:48:00   411
# 1            90011083   1,01,2009  13:30:00   511
# 2            90011208   1,01,2009  15:20:00   407
# 3            90011218   1,01,2009  15:10:00   210
# 4            90011289   1,01,2009  17:00:00   411
# ...               ...         ...       ...   ...
# 319532      193652089  12,31,2019  20:34:00   105
# 319533      193650336  12,31,2019   4:32:00   206
# 319534      193650603  12,31,2019   9:40:00   404
# 319535      193651760  12,31,2019  19:00:00   404
# 319536      193652591  12,31,2019  20:55:00   406
#
#                            Location  Zipcode          UCR Literal  UCR #  \
# 0              2841 GREENBRIAR PKWY    30331  LARCENY-NON VEHICLE    630
# 1                    12 BROAD ST SW    30303  LARCENY-NON VEHICLE    630
# 2       3500 MARTIN L KING JR DR SW    30331  LARCENY-NON VEHICLE    630
# 3              3393 PEACHTREE RD NE    30326  LARCENY-NON VEHICLE    630
# 4           2841 GREENBRIAR PKWY SW    30331  LARCENY-NON VEHICLE    630
# ...                             ...      ...                  ...    ...
# 319532            1385 SHARON ST NW    30314          AGG ASSAULT    420
# 319533              262 PHARR RD NE    30305          AGG ASSAULT    410
# 319534           689 CASCADE AVE SW    30310          AGG ASSAULT    410
# 319535           763 CASCADE AVE SW    30310          AGG ASSAULT    410
# 319536             237 PEYTON PL SW    30311          AGG ASSAULT    410
#
#                Neighborhood  Latitude  Longitude Possible Date New  Poss YEAR
# 0                Greenbriar  33.68845  -84.49328          1/1/2009       2009
# 1                  Downtown  33.75320  -84.39201          1/1/2009       2009
# 2                Adamsville  33.75735  -84.50282          1/1/2009       2009
# 3                     Lenox  33.84676  -84.36212          1/1/2009       2009
# 4                Greenbriar  33.68677  -84.49773          1/1/2009       2009
# ...                     ...       ...        ...               ...        ...
# 319532         Hunter Hills  33.75486  -84.43287        12/31/2019       2019
# 319533     Buckhead Village  33.83732  -84.37860        12/31/2019       2019
# 319534             Westview  33.73636  -84.43680        12/31/2019       2019
# 319535             Westview  33.73483  -84.43750        12/31/2019       2019
# 319536  Cascade Avenue/Road  33.72518  -84.45013        12/31/2019       2019
#
# [319537 rows x 13 columns]

# %%
#crime_zip['Poss Time Hour'] =  pd.to_datetime(crime_zip['Poss Time'], format ='%H:%M:%S').dt.hour
#crime_zip

crime_zip['Poss Time New'] = crime_zip['Poss Time'].str.split(":").str[0]
crime_zip
# Out:
#         Report Number Report Date Poss Time  Beat  \
# 0            90010930   1,01,2009  11:48:00   411
# 1            90011083   1,01,2009  13:30:00   511
# 2            90011208   1,01,2009  15:20:00   407
# 3            90011218   1,01,2009  15:10:00   210
# 4            90011289   1,01,2009  17:00:00   411
# ...               ...         ...       ...   ...
# 319532      193652089  12,31,2019  20:34:00   105
# 319533      193650336  12,31,2019   4:32:00   206
# 319534      193650603  12,31,2019   9:40:00   404
# 319535      193651760  12,31,2019  19:00:00   404
# 319536      193652591  12,31,2019  20:55:00   406
#
#                            Location  Zipcode          UCR Literal  UCR #  \
# 0              2841 GREENBRIAR PKWY    30331  LARCENY-NON VEHICLE    630
# 1                    12 BROAD ST SW    30303  LARCENY-NON VEHICLE    630
# 2       3500 MARTIN L KING JR DR SW    30331  LARCENY-NON VEHICLE    630
# 3              3393 PEACHTREE RD NE    30326  LARCENY-NON VEHICLE    630
# 4           2841 GREENBRIAR PKWY SW    30331  LARCENY-NON VEHICLE    630
# ...                             ...      ...                  ...    ...
# 319532            1385 SHARON ST NW    30314          AGG ASSAULT    420
# 319533              262 PHARR RD NE    30305          AGG ASSAULT    410
# 319534           689 CASCADE AVE SW    30310          AGG ASSAULT    410
# 319535           763 CASCADE AVE SW    30310          AGG ASSAULT    410
# 319536             237 PEYTON PL SW    30311          AGG ASSAULT    410
#
#                Neighborhood  Latitude  Longitude Possible Date New  Poss YEAR  \
# 0                Greenbriar  33.68845  -84.49328          1/1/2009       2009
# 1                  Downtown  33.75320  -84.39201          1/1/2009       2009
# 2                Adamsville  33.75735  -84.50282          1/1/2009       2009
# 3                     Lenox  33.84676  -84.36212          1/1/2009       2009
# 4                Greenbriar  33.68677  -84.49773          1/1/2009       2009
# ...                     ...       ...        ...               ...        ...
# 319532         Hunter Hills  33.75486  -84.43287        12/31/2019       2019
# 319533     Buckhead Village  33.83732  -84.37860        12/31/2019       2019
# 319534             Westview  33.73636  -84.43680        12/31/2019       2019
# 319535             Westview  33.73483  -84.43750        12/31/2019       2019
# 319536  Cascade Avenue/Road  33.72518  -84.45013        12/31/2019       2019
#
#        Poss Time New
# 0                 11
# 1                 13
# 2                 15
# 3                 15
# 4                 17
# ...              ...
# 319532            20
# 319533             4
# 319534             9
# 319535            19
# 319536            20
#
# [319537 rows x 14 columns]

# %%
crime_zip['Poss Time New'] = crime_zip['Poss Time New'] +":00:00"
crime_zip
# Out:
#         Report Number Report Date Poss Time  Beat  \
# 0            90010930   1,01,2009  11:48:00   411
# 1            90011083   1,01,2009  13:30:00   511
# 2            90011208   1,01,2009  15:20:00   407
# 3            90011218   1,01,2009  15:10:00   210
# 4            90011289   1,01,2009  17:00:00   411
# ...               ...         ...       ...   ...
# 319532      193652089  12,31,2019  20:34:00   105
# 319533      193650336  12,31,2019   4:32:00   206
# 319534      193650603  12,31,2019   9:40:00   404
# 319535      193651760  12,31,2019  19:00:00   404
# 319536      193652591  12,31,2019  20:55:00   406
#
#                            Location  Zipcode          UCR Literal  UCR #  \
# 0              2841 GREENBRIAR PKWY    30331  LARCENY-NON VEHICLE    630
# 1                    12 BROAD ST SW    30303  LARCENY-NON VEHICLE    630
# 2       3500 MARTIN L KING JR DR SW    30331  LARCENY-NON VEHICLE    630
# 3              3393 PEACHTREE RD NE    30326  LARCENY-NON VEHICLE    630
# 4           2841 GREENBRIAR PKWY SW    30331  LARCENY-NON VEHICLE    630
# ...                             ...      ...                  ...    ...
# 319532            1385 SHARON ST NW    30314          AGG ASSAULT    420
# 319533              262 PHARR RD NE    30305          AGG ASSAULT    410
# 319534           689 CASCADE AVE SW    30310          AGG ASSAULT    410
# 319535           763 CASCADE AVE SW    30310          AGG ASSAULT    410
# 319536             237 PEYTON PL SW    30311          AGG ASSAULT    410
#
#                Neighborhood  Latitude  Longitude Possible Date New  Poss YEAR  \
# 0                Greenbriar  33.68845  -84.49328          1/1/2009       2009
# 1                  Downtown  33.75320  -84.39201          1/1/2009       2009
# 2                Adamsville  33.75735  -84.50282          1/1/2009       2009
# 3                     Lenox  33.84676  -84.36212          1/1/2009       2009
# 4                Greenbriar  33.68677  -84.49773          1/1/2009       2009
# ...                     ...       ...        ...               ...        ...
# 319532         Hunter Hills  33.75486  -84.43287        12/31/2019       2019
# 319533     Buckhead Village  33.83732  -84.37860        12/31/2019       2019
# 319534             Westview  33.73636  -84.43680        12/31/2019       2019
# 319535             Westview  33.73483  -84.43750        12/31/2019       2019
# 319536  Cascade Avenue/Road  33.72518  -84.45013        12/31/2019       2019
#
#        Poss Time New
# 0           11:00:00
# 1           13:00:00
# 2           15:00:00
# 3           15:00:00
# 4           17:00:00
# ...              ...
# 319532      20:00:00
# 319533       4:00:00
# 319534       9:00:00
# 319535      19:00:00
# 319536      20:00:00
#
# [319537 rows x 14 columns]

# %%
crime_zip['DATE'] = crime_zip['Possible Date New'] + ' '+crime_zip['Poss Time New']
crime_zip
# Out:
#         Report Number Report Date Poss Time  Beat  \
# 0            90010930   1,01,2009  11:48:00   411
# 1            90011083   1,01,2009  13:30:00   511
# 2            90011208   1,01,2009  15:20:00   407
# 3            90011218   1,01,2009  15:10:00   210
# 4            90011289   1,01,2009  17:00:00   411
# ...               ...         ...       ...   ...
# 319532      193652089  12,31,2019  20:34:00   105
# 319533      193650336  12,31,2019   4:32:00   206
# 319534      193650603  12,31,2019   9:40:00   404
# 319535      193651760  12,31,2019  19:00:00   404
# 319536      193652591  12,31,2019  20:55:00   406
#
#                            Location  Zipcode          UCR Literal  UCR #  \
# 0              2841 GREENBRIAR PKWY    30331  LARCENY-NON VEHICLE    630
# 1                    12 BROAD ST SW    30303  LARCENY-NON VEHICLE    630
# 2       3500 MARTIN L KING JR DR SW    30331  LARCENY-NON VEHICLE    630
# 3              3393 PEACHTREE RD NE    30326  LARCENY-NON VEHICLE    630
# 4           2841 GREENBRIAR PKWY SW    30331  LARCENY-NON VEHICLE    630
# ...                             ...      ...                  ...    ...
# 319532            1385 SHARON ST NW    30314          AGG ASSAULT    420
# 319533              262 PHARR RD NE    30305          AGG ASSAULT    410
# 319534           689 CASCADE AVE SW    30310          AGG ASSAULT    410
# 319535           763 CASCADE AVE SW    30310          AGG ASSAULT    410
# 319536             237 PEYTON PL SW    30311          AGG ASSAULT    410
#
#                Neighborhood  Latitude  Longitude Possible Date New  Poss YEAR  \
# 0                Greenbriar  33.68845  -84.49328          1/1/2009       2009
# 1                  Downtown  33.75320  -84.39201          1/1/2009       2009
# 2                Adamsville  33.75735  -84.50282          1/1/2009       2009
# 3                     Lenox  33.84676  -84.36212          1/1/2009       2009
# 4                Greenbriar  33.68677  -84.49773          1/1/2009       2009
# ...                     ...       ...        ...               ...        ...
# 319532         Hunter Hills  33.75486  -84.43287        12/31/2019       2019
# 319533     Buckhead Village  33.83732  -84.37860        12/31/2019       2019
# 319534             Westview  33.73636  -84.43680        12/31/2019       2019
# 319535             Westview  33.73483  -84.43750        12/31/2019       2019
# 319536  Cascade Avenue/Road  33.72518  -84.45013        12/31/2019       2019
#
#        Poss Time New                 DATE
# 0           11:00:00    1/1/2009 11:00:00
# 1           13:00:00    1/1/2009 13:00:00
# 2           15:00:00    1/1/2009 15:00:00
# 3           15:00:00    1/1/2009 15:00:00
# 4           17:00:00    1/1/2009 17:00:00
# ...              ...                  ...
# 319532      20:00:00  12/31/2019 20:00:00
# 319533       4:00:00   12/31/2019 4:00:00
# 319534       9:00:00   12/31/2019 9:00:00
# 319535      19:00:00  12/31/2019 19:00:00
# 319536      20:00:00  12/31/2019 20:00:00
#
# [319537 rows x 15 columns]

# %%
crime_zip.to_csv("crime_2009-2019_zip.csv", encoding='utf-8', index= False)

# %%
import psycopg2

#establishing the connection
conn = psycopg2.connect(
   database="postgres", user='postgres', password='postgres', host='127.0.0.1', port= '5432'
)
conn.autocommit = True

#Creating a cursor object using the cursor() method
cursor = conn.cursor()
cursor.execute("DROP DATABASE IF EXISTS crime_db_final")
#Preparing query to create a database
sql = '''CREATE database crime_db_final''';

#Creating a database
cursor.execute(sql)
print("Database created successfully........")

#Closing the connection
conn.close()
# Out:
# Database created successfully........

# %%
#Establishing the connection
conn = psycopg2.connect(
   database="crime_db_final", user='postgres', password='postgres', host='127.0.0.1', port= '5432'
)
#Creating a cursor object using the cursor() method
cursor = conn.cursor()

#Droping  table if already exists.
cursor.execute("DROP TABLE IF EXISTS crime_new")
cursor.execute("DROP TABLE IF EXISTS crime_ml")


print("Table dropped successfully........")
conn.commit()
#Closing the connection
conn.close()
# Out:
# Table dropped successfully........

# %% [markdown]
# #Establishing the connection
# conn = psycopg2.connect(
#    database="crime_final_db", user='postgres', password='postgres', host='127.0.0.1', port= '5432'
# )
# #Creating a cursor object using the cursor() method
# cursor = conn.cursor()
#
# #Doping EMPLOYEE table if already exists.
# cursor.execute("TRUNCATE crime_ml; DELETE FROM crime_ml;")
# print("Table data deleted successfully........")
# conn.commit()
# #Closing the connection
# conn.close()

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://postgres:postgres@localhost:5432/crime_db_final')


clean_new_crime.to_sql('crime_new',engine,index=False)
crime_zip.to_sql('crime_ml',engine,index=False)
engine.dispose()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-44-9d38d1817211> in <module>
#       4
#       5 clean_new_crime.to_sql('crime_new',engine,index=False)
# ----> 6 crime_zip.to_sql('crime_ml',engine,index=False)
#       7 engine.dispose()
#
# ~\anaconda3\envs\Pythondata\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2661             chunksize=chunksize,
#    2662             dtype=dtype,
# -> 2663             method=method,
#    2664         )
#    2665
#
# ~\anaconda3\envs\Pythondata\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     519         chunksize=chunksize,
#     520         dtype=dtype,
# --> 521         method=method,
#     522     )
#     523
#
# ~\anaconda3\envs\Pythondata\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1315         )
#    1316         table.create()
# -> 1317         table.insert(chunksize, method=method)
#    1318         if not name.isdigit() and not name.islower():
#    1319             # check for potentially case sensitivity issues (GH7815)
#
# ~\anaconda3\envs\Pythondata\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     753
#     754                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 755                 exec_insert(conn, keys, chunk_iter)
#     756
#     757     def _query_iterator(
#
# ~\anaconda3\envs\Pythondata\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     667         """
#     668         data = [dict(zip(keys, row)) for row in data_iter]
# --> 669         conn.execute(self.table.insert(), data)
#     670
#     671     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\anaconda3\envs\Pythondata\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1009             )
#    1010         else:
# -> 1011             return meth(self, multiparams, params)
#    1012
#    1013     def _execute_function(self, func, multiparams, params):
#
# ~\anaconda3\envs\Pythondata\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# ~\anaconda3\envs\Pythondata\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1128             distilled_params,
#    1129             compiled_sql,
# -> 1130             distilled_params,
#    1131         )
#    1132         if self._has_events or self.engine._has_events:
#
# ~\anaconda3\envs\Pythondata\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1315         except BaseException as e:
#    1316             self._handle_dbapi_exception(
# -> 1317                 e, statement, parameters, cursor, context
#    1318             )
#    1319
#
# ~\anaconda3\envs\Pythondata\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1512                 )
#    1513             else:
# -> 1514                 util.raise_(exc_info[1], with_traceback=exc_info[2])
#    1515
#    1516         finally:
#
# ~\anaconda3\envs\Pythondata\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~\anaconda3\envs\Pythondata\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1255                 if not evt_handled:
#    1256                     self.dialect.do_executemany(
# -> 1257                         cursor, statement, parameters, context
#    1258                     )
#    1259             elif not parameters and context.no_parameters:
#
# ~\anaconda3\envs\Pythondata\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     871     def do_executemany(self, cursor, statement, parameters, context=None):
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#     875
#
# ~\anaconda3\envs\Pythondata\lib\encodings\utf_8.py in decode(input, errors)
#      13 encode = codecs.utf_8_encode
#      14
# ---> 15 def decode(input, errors='strict'):
#      16     return codecs.utf_8_decode(input, errors, True)
#      17
#
# KeyboardInterrupt:
